# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/KDT/data/mpg.csv')
display(df)
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
# 1.
group_by_manufacture = df.groupby('manufacturer')
print(group_by_manufacture.cty.mean().idxmax())
# Out:
# honda

# %%
# 2.
group_by_model = df.groupby('model')
print(group_by_model.hwy.max().idxmax())
# Out:
# jetta

# %%
# 3.
group_by_year = df.groupby('year')
print(group_by_year.cty.mean().idxmax())
# Out:
# 1999

# %%
# 4.
group_by_class = df.groupby('class')
print(group_by_class.hwy.max().idxmax())
# Out:
# compact

# %%
# 5.
group_by_cyl = df.loc[df['cyl'] == 4].groupby('model')
print(group_by_cyl.displ.min().idxmin())
# Out:
# civic

# %%
# 6.
group_by_manufacture = df.groupby('manufacturer')
print(group_by_manufacture.count().model.idxmax())
# Out:
# dodge

# %%
# 7.
group_by_fl = df.groupby('fl')
print(group_by_fl.fl.count().idxmax())
# Out:
# r

# %%
# 8.
group_by_drv = df.groupby('drv')
print(group_by_drv.hwy.max().idxmax())
# Out:
# f

# %%
# 9.
group_by_trans = df.groupby('trans')
print(group_by_trans.trans.count().idxmax())
# Out:
# auto(l4)

# %%
# 10.
group_by_displ = df.loc[df['displ'] <= 2.0].groupby('model')
print(group_by_displ.cty.max().idxmax())
# Out:
# new beetle

# %%
# 11.
df['hwy_cty'] = df['hwy'] - df['cty']
group_by_model = df.groupby('model')
print(group_by_model.hwy_cty.max().idxmax())
# Out:
# civic

# %%
# 12.
group_by_class = df.groupby('class')
print(group_by_class.displ.mean().idxmax())
# Out:
# 2seater

# %%
# 13.
group_by_fl = df.groupby('fl')
print(group_by_fl.hwy.max().idxmax())
# Out:
# d

# %%
# 14.
group_by_manufacture = df.loc[df['displ'] >= 3.0].groupby('manufacturer')
print(group_by_manufacture.hwy.mean().idxmax())
# Out:
# hyundai

# %%
# 15.
group_by_model = df.loc[df['cyl'] == 4].groupby('model')
print(group_by_model.cty.min().idxmin())
# Out:
# 4runner 4wd

# %%
# 16.
group_by_manufacture = df.loc[df['year'] == 2008].groupby('manufacturer')
print(group_by_manufacture.cty.mean().idxmax())
# Out:
# honda

# %%
# 17.
group_by_model = df.loc[df['displ'] >= 2.5].groupby('model')
print(group_by_model.cty.max().idxmax())
# Out:
# altima

# %%
# 18.
group_by_model = df.groupby('model')
print(group_by_model.cyl.max().idxmax())
# Out:
# 4runner 4wd

# %%
# 19.
group_by_manufacture = df.groupby('manufacturer')
print(group_by_manufacture.displ.mean().idxmax())
# Out:
# lincoln

# %%
# 20.
group_by_manufacture = df.groupby('manufacturer')
print(group_by_manufacture.cty.min().idxmin())
# Out:
# dodge
